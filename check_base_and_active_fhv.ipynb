# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Base資訊

# %%
base = pd.read_csv('current_bases.csv')
base.head()
# Out:
#   License Number                   Entity Name  Telephone Number SHL Endorsed  \
# 0         B03377                  JUMPRYDZ LLC        7328392801           No
# 1         B03281    JARPA TRANSPORTATION CORP.        7186350047           No
# 2         B01339           R C AUDUBON SVC INC        2129238787          Yes
# 3         B03278  GEWESEN TRANSPORTATION CORP.        9739542775           No
# 4         B03109                     ROLUX INC        9178652793           No
#
#   Building                       Street           City State Postcode  \
# 0      317           GEORGE ST  STE 320  NEW BRUNSWICK    NJ    08901
# 1     2825      THIRD AVENUE  SUITE 301          BRONX    NY    10455
# 2     2224             AMSTERDAM AVENUE       NEW YORK    NY    10032
# 3      175                VARICK STREET       NEW YORK    NY    10014
# 4   160-23  ROCKAWAY BOULEVARD  SUITE 4        JAMAICA    NY    11434
#
#      Type of Base   Latitude  Longitude        Date      Time  \
# ...

# %%
base.shape
# Out:
# (825, 15)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   License Number    825 non-null    object
#  1   Entity Name       825 non-null    object
#  2   Telephone Number  825 non-null    int64
#  3   SHL Endorsed      825 non-null    object
#  4   Building          825 non-null    object
#  5   Street            825 non-null    object
#  6   City              825 non-null    object
#  7   State             825 non-null    object
#  8   Postcode          825 non-null    object
#  9   Type of Base      825 non-null    object
#  10  Latitude          822 non-null    float64
#  11  Longitude         822 non-null    float64
#  12  Date              825 non-null    object
#  13  Time              825 non-null    object
#  14  Location          822 non-null    object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 96.8+ KB

# %% [markdown]
# License有效的車子紀錄

# %%
active_fhv = pd.read_csv('fhv_active.csv')
active_fhv.head()
# Out:
#   Active Vehicle License Number                  Name      License Type  \
# 0    YES                5392883     DELAROSA,MANUEL,D  FOR HIRE VEHICLE
# 1    YES                5899407    GOFRAN,,MOHAMMAD,A  FOR HIRE VEHICLE
# 2    YES                5617730       PHUNTSOK,TENZIN  FOR HIRE VEHICLE
# 3    YES                5807280  RODRIGUEZVILLAFN,F,A  FOR HIRE VEHICLE
# 4    YES                5865513     TEJADA,TEJADA,M,L  FOR HIRE VEHICLE
#
#   Expiration Date Permit License Number DMV License Plate Number  \
# 0      03/24/2025                   NaN                 T602431C
# 1      12/24/2024                   NaN                 T780997C
# 2      05/14/2025                   NaN                 T665230C
# 3      08/29/2023                   NaN                 T749328C
# 4      05/07/2024                   NaN                 T769520C
#
#   Vehicle VIN Number Wheelchair Accessible Certification Date  ...  \
# 0  4T1BF1FK5HU615813                   NaN                NaN  ...
# ...

# %%
active_fhv.shape
# Out:
# (97370, 23)

# %%
active_fhv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97370 entries, 0 to 97369
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Active                    97370 non-null  object
#  1   Vehicle License Number    97370 non-null  object
#  2   Name                      97370 non-null  object
#  3   License Type              97370 non-null  object
#  4   Expiration Date           97370 non-null  object
#  5   Permit License Number     1107 non-null   object
#  6   DMV License Plate Number  97370 non-null  object
#  7   Vehicle VIN Number        97370 non-null  object
#  8   Wheelchair Accessible     5767 non-null   object
#  9   Certification Date        3957 non-null   object
#  10  Hack Up Date              3940 non-null   object
#  11  Vehicle Year              97370 non-null  int64
#  12  Base Number               97370 non-null  object
# ...

# %%
active_fhv.iloc[:, 12:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97370 entries, 0 to 97369
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Base Number            97370 non-null  object
#  1   Base Name              97370 non-null  object
#  2   Base Type              97370 non-null  object
#  3   VEH                    10943 non-null  object
#  4   Base Telephone Number  97370 non-null  object
#  5   Website                7040 non-null   object
#  6   Base Address           97370 non-null  object
#  7   Reason                 97370 non-null  object
#  8   Order Date             0 non-null      float64
#  9   Last Date Updated      97370 non-null  object
#  10  Last Time Updated      97370 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 8.2+ MB

# %% [markdown]
# 檢查車有效的fhv車所屬base的註冊地址

# %%
active_fhv_ny = active_fhv[active_fhv['Base Address'].str.contains('CA') == True]
active_fhv_ny.shape
# Out:
# (77158, 23)

# %% [markdown]
# 檢查調度基地的登記地址

# %%
base_not_ny = base[base['State'].str.contains('NY') == False]
base_not_ny.shape
# Out:
# (31, 15)

# %%
base_not_ny
# Out:
#     License Number                                        Entity Name  \
# 0           B03377                                       JUMPRYDZ LLC
# 80          B02120                                HARRISON GLOBAL LLC
# 91          B02173                                     ADMIRE LLP LLC
# 96          B03168                          KAYROS TRANSPORTATION INC
# 107         B03074                           BLACKBIRD WORLDWIDE CORP
# 149         B03507                         GOLDEN BIRD LIMOUSINES LLC
# 160         B02724                                      CORE CAR, INC
# 180         B02256                     EUROPE LIMOUSINE SERVICE, INC.
# 225         B01871                     ALPINE LIMOUSINE SERVICE, INC.
# 232         B03486                                         OCCSER LLC
# 260         B03320                              LIMOLINK INCORPORATED
# 364         B03429                        EURO LINE LIMO SERVICES INC
# ...
